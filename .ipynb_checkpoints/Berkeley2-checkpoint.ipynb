# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import cv2

# %%
arr = []
with open("data.csv", newline='' ) as csvfile:
    for row in csvfile.readlines()[1:]:
        row = row.rstrip()
        arr.append(row.split(','))
       #print(row)

iui = []
for ar in arr:
    iui.append(ar[0] + " " +  ar[1])
#print(iui)
print(len(set(iui)))
# Out:
# 300

# %%
dataFrame = pd.DataFrame(arr, columns = ["gene_id","spot_id","time","spot_fluorescence"])
dataFrame.set_index(['gene_id', 'spot_id'], inplace = True)
dataFrame.sort_index(inplace=True)
dataFrame
# Out:
#                  time    spot_fluorescence
# gene_id spot_id
# 1       1           0                    0
#         1          20                    0
#         1          40                    0
#         1          60                    0
#         1          80                    0
#         1         100                    0
#         1         120                    0
#         1         140                    0
#         1         160     23.3193129599779
#         1         180  0.00969783968923776
#         1         200    0.430429748780914
#         1         220     4.92303863597771
#         1         240     12.2912902042571
#         1         260     19.5528804775006
#         1         280     17.6935436745371
#         1         300      7.8443183662049
#         1         320     11.8961434674836
#         1         340     19.5775999837419
#         1         360     7.02775998554446
#         1         380     17.9657729155303
#         1         400      29.402384229475
#         1         420     44.6816889645892
#         1         440     55.1917961092726
#         1         460     63.5599842512895
#         1         480     66.7495539317671
#         1         500     52.9336909646833
#         1         520     32.6836921442997
#         1         540      43.114360934924
#         1         560     57.2943426436335
#         1         580     69.9669175980726
# ...               ...                  ...
# 2       99       2420                    0
#         99       2440                    0
#         99       2460                    0
#         99       2480                    0
#         99       2500                    0
#         99       2520                    0
#         99       2540                    0
#         99       2560                    0
#         99       2580                    0
#         99       2600                    0
#         99       2620                    0
#         99       2640                    0
#         99       2660                    0
#         99       2680                    0
#         99       2700                    0
#         99       2720                    0
#         99       2740                    0
#         99       2760                    0
#         99       2780                    0
#         99       2800                    0
#         99       2820                    0
#         99       2840                    0
#         99       2860                    0
#         99       2880                    0
#         99       2900                    0
#         99       2920                    0
#         99       2940                    0
#         99       2960                    0
#         99       2980                    0
#         99       3000                    0
#
# [45300 rows x 2 columns]

# %%
features = []
curr_geneid = 1
curr_spotid = 1
xarr = []
yarr = []
for index, row in dataFrame[:300].iterrows():
    curr_geneid, curr_spotid = str(curr_geneid), str(curr_spotid)
    #index[0], curr_geneid, index[1], curr_spotid = int(index[0]), int(curr_geneid), int(index[1]), int(curr_spotid)
    if(index[0] == curr_geneid and index[1] == curr_spotid):
        xarr.append(row["time"])
        yarr.append(row["spot_fluorescence"])
        #print(row["time"])
        #print(row["spot_fluorescence"])
    else:
        #xarr, yarr are complete
        yarr = [float(x) for x in yarr]
        xarr = [float(x) for x in xarr]
        plt.figure()
        plt.ylabel("spot_fluorescence")
        plt.xlabel("Time(seconds)")
        plt.plot(xarr, yarr)
        #plt.show()
        img_name = "gene" + str(curr_geneid) + "/spotid" + str(curr_spotid) + ".png"
        plt.savefig(img_name)
        #process data after plotted(no data lost)
        #remove 0s on head and tail of graph
        condition = True
        while(condition):
            if(yarr[0] < 0.01):
                yarr.pop(0)
                xarr.pop(0)
            else:
                condition = False
        condition = True
        while(condition):
            if(yarr[-1] < 0.01):
                yarr.pop()
                xarr.pop()
            else:
                condition = False
        '''
        plt.figure()
        plt.ylabel("spot_fluorescence")
        plt.xlabel("Time(seconds)")
        plt.plot(xarr, yarr)
        plt.show()
        '''
        avg = np.mean(yarr)
        std = np.std(yarr)
        
        curr_geneid = int(index[0])
        curr_spotid = int(index[1])
        xarr = []
        yarr = []
